# %% [markdown]
# Scraping from IMDB

# %%
from bs4 import BeautifulSoup
import requests
import time, os
import re
import pandas as pd
import time
import pickle

from currency_converter import CurrencyConverter
from datetime import date

# %% [markdown]
# Loading previous pickled dataframe

# %%
earliestrelease_notdomestic_movies = pd.read_pickle('earliestrelease_notdomestic_movies.pickle')

# %%
earliestrelease_notdomestic_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1659 entries, Hero to News from Planet Mars
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   link_stub                                 1659 non-null   object
#  1   gross_rank                                1659 non-null   float64
#  2   lifetime_gross                            1659 non-null   float64
#  3   max_theaters                              1651 non-null   float64
#  4   domestic_opening                          1591 non-null   float64
#  5   num_opening_theaters                      1593 non-null   float64
#  6   release_date                              1659 non-null   datetime64[ns]
#  7   domestic_distributor                      1609 non-null   object
#  8   domestic_total_gross                      1659 non-null   float64
#  9   international_total_gross                 1659 non-null   float64
#  10  budget                                    41 non-null     float64
#  11  earliest_release_location                 1659 non-null   object
#  12  rating                                    496 non-null    object
#  13  runtime                                   1612 non-null   float64
#  14  genres                                    1659 non-null   object
#  15  original_release_markets_num              366 non-null    object
#  16  crew                                      1649 non-null   object
#  17  cast                                      1649 non-null   object
#  18  earliest_release_location_opening_gross   1524 non-null   float64
#  19  earliest_release_location_original_gross  1653 non-null   float64
# dtypes: datetime64[ns](1), float64(11), object(8)
# memory usage: 272.2+ KB

# %%
earliestrelease_notdomestic_movies.link_stub.head()
# Out:
# Hero               /title/tt0299977/?ref_=bo_ge_table_3
# Parasite           /title/tt6751668/?ref_=bo_ge_table_4
# Pan's Labyrinth    /title/tt0457430/?ref_=bo_ge_table_6
# Amélie             /title/tt0211915/?ref_=bo_ge_table_7
# Fearless           /title/tt0446059/?ref_=bo_ge_table_8
# Name: link_stub, dtype: object

# %%
new_link_stubs = []
for link in earliestrelease_notdomestic_movies.link_stub:
    new_link_stubs.append(link.split('?')[0])

new_link_stubs
# Out:
# ['/title/tt0299977/',
#  '/title/tt6751668/',
#  '/title/tt0457430/',
#  '/title/tt0211915/',
#  '/title/tt0446059/',
#  '/title/tt4849438/',
#  '/title/tt0373074/',
#  '/title/tt0318462/',
#  '/title/tt0265343/',
#  '/title/tt0245574/',
#  '/title/tt0441909/',
#  '/title/tt0427954/',
#  '/title/tt5935704/',
#  '/title/tt0405094/',
#  '/title/tt0237534/',
#  '/title/tt0385004/',
#  '/title/tt2338151/',
#  '/title/tt0450188/',
#  '/title/tt1675434/',
#  '/title/tt1132620/',
#  '/title/tt0245429/',
#  '/title/tt0287467/',
#  '/title/tt4643580/',
#  '/title/tt1833673/',
#  '/title/tt6452574/',
#  '/title/tt1668200/',
#  '/title/tt1216487/',
#  '/title/tt0317248/',
#  '/title/tt0464141/',
#  '/title/tt1832382/',
#  '/title/tt1602620/',
#  '/title/tt1462900/',
#  '/title/tt0473444/',
#  '/title/tt0344510/',
#  '/title/tt1305806/',
#  '/title/tt4832640/',
#  '/title/tt0161860/',
#  '/title/tt0362225/',
#  '/title/tt1035736/',
#  '/title/tt7605074/',
#  '/title/tt0313196/',
#  '/title/tt0416044/',
#  '/title/tt0048308/',
#  '/title/tt0498097/',
#  '/title/tt4379728/',
#  '/title/tt3278330/',
#  '/title/tt7962598/',
#  '/title/tt0879843/',
#  '/title/tt0417189/',
#  '/title/tt2106741/',
#  '/title/tt7158582/',
#  '/title/tt1934269/',
#  '/title/tt0997246/',
#  '/title/tt8119752/',
#  '/title/tt7075594/',
#  '/title/tt1170404/',
#  '/title/tt0301524/',
#  '/title/tt4353996/',
#  '/title/tt2387513/',
#  '/title/tt4726636/',
#  '/title/tt4428814/',
#  '/title/tt7156436/',
#  '/title/tt0814666/',
#  '/title/tt2406676/',
#  '/title/tt0887732/',
#  '/title/tt0405866/',
#  '/title/tt3054798/',
#  '/title/tt6904272/',
#  '/title/tt1236371/',
#  '/title/tt1379182/',
#  '/title/tt1229366/',
#  '/title/tt6452332/',
#  '/title/tt7204348/',
#  '/title/tt6763252/',
#  '/title/tt0319237/',
#  '/title/tt1368491/',
#  '/title/tt4374460/',
#  '/title/tt4273886/',
#  '/title/tt5974388/',
#  '/title/tt1188983/',
#  '/title/tt4621872/',
#  '/title/tt0318780/',
#  '/title/tt6399158/',
#  '/title/tt0910559/',
#  '/title/tt10161238/',
#  '/title/tt0996605/',
#  '/title/tt7607940/',
#  '/title/tt7108976/',
#  '/title/tt7881542/',
#  '/title/tt10550884/',
#  '/title/tt3696086/',
#  '/title/tt0291988/',
#  '/title/tt0785035/',
#  '/title/tt1204773/',
#  '/title/tt1654829/',
#  '/title/tt1951166/',
#  '/title/tt9490414/',
#  '/title/tt1736633/',
#  '/title/tt1702014/',
#  '/title/tt9225192/',
#  '/title/tt2184331/',
#  '/title/tt1361835/',
#  '/title/tt1221141/',
#  '/title/tt0359045/',
#  '/title/tt1555149/',
#  '/title/tt4937156/',
#  '/title/tt6398666/',
#  '/title/tt6117702/',
#  '/title/tt0192657/',
#  '/title/tt10927906/',
#  '/title/tt5729246/',
#  '/title/tt8367080/',
#  '/title/tt0281364/',
#  '/title/tt2187115/',
#  '/title/tt6352548/',
#  '/title/tt1229381/',
#  '/title/tt0052893/',
#  '/title/tt5011290/',
#  '/title/tt0346094/',
#  '/title/tt0286476/',
#  '/title/tt2534634/',
#  '/title/tt0420206/',
#  '/title/tt1618447/',
#  '/title/tt8956390/',
#  '/title/tt6485776/',
#  '/title/tt1884268/',
#  '/title/tt5749596/',
#  '/title/tt2063008/',
#  '/title/tt5576336/',
#  ...]

# %%
def get_movie_value(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find(text=re.compile(field_name))
    
    if not obj: 
        return None
    
    # this works for most of the values
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text 
    else:
        return None

# %%
def get_movie_dict(link):
    base_url = 'https://www.imdb.com'
    
    #Create full url to scrape
    url = base_url + link
    
    #Request HTML and parse
    for i in range(5): 
        try:
            response = requests.get(url)
        except:
            time.sleep(10) 
            continue
        else:
            break
    page = response.text
    soup = BeautifulSoup(page,"lxml")
    
    headers = ['link_stub', 'language', 'budget']
    
    try:
        language = get_movie_value(soup, 'Language:')
    except:
        language = None 
    
    try:
        first = soup.find(text=re.compile('Budget:'))
        next_element = first.findNext()
        raw_budget = next_element.previous
        budget = raw_budget.split('\n')[0]
    except: 
        budget = None 
        
    #Create movie dictionary and return
    movie_dict = dict(zip(headers, [link, language, budget]))

    return movie_dict

# %%
fl_movies_imdb_list = [] #saving the info to a dictionary OUTSIDE the function

for link in new_link_stubs:
    fl_movies_imdb_list.append(get_movie_dict(link))
    
fl_movies_imdb = pd.DataFrame(fl_movies_imdb_list)  #converting list of dict to df
fl_movies_imdb.set_index('link_stub', inplace=True) 

import pickle #immediately pickling dataframe
fl_movies_imdb.to_pickle('fl_movies_imdb.pickle')

# %%
fl_movies_imdb['budget'].isna().sum()
# Out:
# 1081

# %%
fl_movies_imdb.shape
# Out:
# (1659, 2)

# %%
fl_movies_imdb.tail(10)
# Out:
#                   language        budget
# link_stub
# /title/tt4948452/   French  EUR5,831,000
# /title/tt2167715/    Dutch          None
# /title/tt1289783/   French          None
# /title/tt2361110/   French          None
# /title/tt4428762/   French          None
# /title/tt1503777/   French          None
# /title/tt0312358/   German          None
# /title/tt5091538/   French          None
# /title/tt0821462/   Korean    $2,000,000
# /title/tt5038358/   French  EUR6,300,000

# %%
earliestrelease_notdomestic_movies = pd.read_pickle('earliestrelease_notdomestic_movies.pickle')

# %%
fl_movies_imdb = pd.read_pickle('fl_movies_imdb.pickle')

# %%
earliestrelease_notdomestic_movies.shape
# Out:
# (1659, 20)

# %%
earliestrelease_notdomestic_movies['link_stub'] = earliestrelease_notdomestic_movies['link_stub'].apply(lambda x: x.split('?')[0])  
earliestrelease_notdomestic_movies.head(2)
# Out:
#                   link_stub  gross_rank  lifetime_gross  max_theaters  \
# Hero      /title/tt0299977/         3.0      53710019.0        2175.0
# Parasite  /title/tt6751668/         4.0      53369749.0        2001.0
#
#           domestic_opening  num_opening_theaters release_date  \
# Hero            17800000.0                2031.0   2004-08-27
# Parasite          393216.0                   3.0   2019-10-11
#
#          domestic_distributor  domestic_total_gross  \
# Hero                  Miramax            53710019.0
# Parasite                 Neon            53369749.0
#
#           international_total_gross      budget earliest_release_location  \
# Hero                    123685538.0  31000000.0               APAC, China
# Parasite                205484917.0  11400000.0               South Korea
#
#          rating  runtime                    genres  \
# Hero      PG-13      NaN  Action Adventure History
# Parasite      R    132.0     Comedy Drama Thriller
#
#          original_release_markets_num  \
# Hero                             None
# Parasite                           34
#
#                                                        crew  \
# Hero      Yimou Zhang Director, Feng Li Writer, Yimou Zh...
# Parasite  Bong Joon Ho Director, Bong Joon Ho Writer, Bo...
#
#                                                        cast  \
# Hero      Jet Li, Tony Chiu-Wai Leung, Maggie Cheung, Zi...
# Parasite  Kang-ho Song, Sun-kyun Lee, Yeo-jeong Cho, Woo...
#
#           earliest_release_location_opening_gross  \
# Hero                                   17800000.0
# Parasite                                 393216.0
#
#           earliest_release_location_original_gross
# Hero                                    53710019.0
# Parasite                                53369749.0

# %%
earliestrelease_notdomestic_movies.reset_index(inplace=True)

# %%
earliestrelease_notdomestic_movies.rename(columns={"index": "title"}, inplace=True)

# %%
fl_movies_wbudget = earliestrelease_notdomestic_movies.merge(fl_movies_imdb, how="outer", on='link_stub')
fl_movies_wbudget.head()
# Out:
#              title          link_stub  gross_rank  lifetime_gross  \
# 0             Hero  /title/tt0299977/         3.0      53710019.0
# 1         Parasite  /title/tt6751668/         4.0      53369749.0
# 2  Pan's Labyrinth  /title/tt0457430/         6.0      37634615.0
# 3           Amélie  /title/tt0211915/         7.0      33225499.0
# 4         Fearless  /title/tt0446059/         8.0      24633730.0
#
#    max_theaters  domestic_opening  num_opening_theaters release_date  \
# 0        2175.0        17800000.0                2031.0   2004-08-27
# 1        2001.0          393216.0                   3.0   2019-10-11
# 2        1143.0          568641.0                  17.0   2006-12-29
# 3         303.0          136470.0                   3.0   2001-11-02
# 4        1810.0        10564000.0                1806.0   2006-09-22
#
#   domestic_distributor  domestic_total_gross  ...  rating  runtime  \
# 0              Miramax            53710019.0  ...   PG-13      NaN
# 1                 Neon            53369749.0  ...       R    132.0
# 2         Picturehouse            37634615.0  ...       R    118.0
# 3              Miramax            33225499.0  ...       R    122.0
# 4       Rogue Pictures            24633730.0  ...   PG-13    104.0
#
#                          genres original_release_markets_num  \
# 0      Action Adventure History                         None
# 1         Comedy Drama Thriller                           34
# 2             Drama Fantasy War                         None
# 3                Comedy Romance                           20
# 4  Action Biography Drama Sport                         None
#
#                                                 crew  \
# 0  Yimou Zhang Director, Feng Li Writer, Yimou Zh...
# 1  Bong Joon Ho Director, Bong Joon Ho Writer, Bo...
# 2  Guillermo del Toro Director, Guillermo del Tor...
# 3  Jean-Pierre Jeunet Director, Guillaume Laurant...
# 4  Ronny Yu Director, Chris Chow Writer, Richard ...
#
#                                                 cast  \
# 0  Jet Li, Tony Chiu-Wai Leung, Maggie Cheung, Zi...
# 1  Kang-ho Song, Sun-kyun Lee, Yeo-jeong Cho, Woo...
# 2  Ivana Baquero, Ariadna Gil, Sergi López, Marib...
# 3  Audrey Tautou, Mathieu Kassovitz, Rufus, Lorel...
# 4                  Jet Li, Li Sun, Yong Dong, Yun Qu
#
#   earliest_release_location_opening_gross  \
# 0                              17800000.0
# 1                                393216.0
# 2                                568641.0
# 3                                136470.0
# 4                              10564000.0
#
#   earliest_release_location_original_gross  language     budget_y
# 0                               53710019.0  Mandarin  $31,000,000
# 1                               53369749.0    Korean  $11,400,000
# 2                               37634615.0   Spanish  $19,000,000
# 3                               33225499.0    French  $10,000,000
# 4                               24633730.0  Mandarin         None
#
# [5 rows x 23 columns]

# %%
fl_movies_wbudget['budget_y'].isna().sum()
# Out:
# 1081

# %%
fl_movies_wbudget.drop(columns=["budget_x", "rating", "original_release_markets_num"], inplace=True)

# %%
fl_movies_wbudget.drop(columns=["link_stub", "gross_rank"], inplace=True)

# %%
fl_movies_wbudget.domestic_distributor.fillna('Missing', inplace=True)

# %%
fl_movies_wbudget.crew.fillna('Missing', inplace=True)
fl_movies_wbudget.cast.fillna('Missing', inplace=True)

# %%
fl_movies_wbudget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1659 entries, 0 to 1658
# Data columns (total 18 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   title                                     1659 non-null   object
#  1   lifetime_gross                            1659 non-null   float64
#  2   max_theaters                              1651 non-null   float64
#  3   domestic_opening                          1591 non-null   float64
#  4   num_opening_theaters                      1593 non-null   float64
#  5   release_date                              1659 non-null   datetime64[ns]
#  6   domestic_distributor                      1659 non-null   object
#  7   domestic_total_gross                      1659 non-null   float64
#  8   international_total_gross                 1659 non-null   float64
#  9   earliest_release_location                 1659 non-null   object
#  10  runtime                                   1612 non-null   float64
#  11  genres                                    1659 non-null   object
#  12  crew                                      1659 non-null   object
#  13  cast                                      1659 non-null   object
#  14  earliest_release_location_opening_gross   1524 non-null   float64
#  15  earliest_release_location_original_gross  1653 non-null   float64
#  16  language                                  1657 non-null   object
#  17  budget_y                                  578 non-null    object
# dtypes: datetime64[ns](1), float64(9), object(8)
# memory usage: 246.3+ KB

# %%
fl_movies_wbudget.rename(columns={"budget_y": "budget"}, inplace=True)

# %%
fl_movies_wbudget['budget'][0]
# Out:
# '$31,000,000'

# %%
currency = []
for budget in fl_movies_wbudget['budget']:
    if budget == None:
        currency.append(None)
    elif budget[0:1] == '$':
        currency.append('USD')
    else:
        currency.append(budget[0:3])
currency
# Out:
# ['USD',
#  'USD',
#  'USD',
#  'USD',
#  None,
#  'INR',
#  'USD',
#  None,
#  'INR',
#  'USD',
#  'EUR',
#  'THB',
#  None,
#  'USD',
#  'USD',
#  'CNY',
#  None,
#  'USD',
#  'EUR',
#  'USD',
#  'USD',
#  None,
#  'USD',
#  None,
#  'USD',
#  'EUR',
#  'EUR',
#  'BRL',
#  'EUR',
#  'USD',
#  'USD',
#  'USD',
#  'USD',
#  'USD',
#  'USD',
#  'USD',
#  'EUR',
#  'EUR',
#  'USD',
#  'USD',
#  'USD',
#  'USD',
#  'USD',
#  'USD',
#  'EUR',
#  'EUR',
#  None,
#  None,
#  'USD',
#  'EUR',
#  'INR',
#  None,
#  'JPY',
#  'USD',
#  'EUR',
#  'USD',
#  'USD',
#  'EUR',
#  None,
#  None,
#  'USD',
#  'USD',
#  None,
#  'USD',
#  'INR',
#  None,
#  None,
#  'INR',
#  'USD',
#  'EUR',
#  'USD',
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  'EUR',
#  None,
#  None,
#  'INR',
#  None,
#  'INR',
#  'USD',
#  'FRF',
#  'EUR',
#  None,
#  None,
#  'USD',
#  'FRF',
#  'INR',
#  'USD',
#  'EUR',
#  None,
#  None,
#  'USD',
#  'USD',
#  'INR',
#  'USD',
#  'EUR',
#  'EUR',
#  None,
#  None,
#  'INR',
#  None,
#  None,
#  'INR',
#  'USD',
#  None,
#  'USD',
#  None,
#  'EUR',
#  'USD',
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  'INR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  'USD',
#  'INR',
#  'KRW',
#  'EUR',
#  'INR',
#  None,
#  'EUR',
#  'AUD',
#  None,
#  'KRW',
#  None,
#  None,
#  None,
#  'USD',
#  'EUR',
#  'INR',
#  'USD',
#  'EUR',
#  'INR',
#  'USD',
#  'EUR',
#  'EUR',
#  None,
#  None,
#  None,
#  'KRW',
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INR',
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  'USD',
#  'USD',
#  'USD',
#  None,
#  None,
#  'EUR',
#  'EUR',
#  'FRF',
#  None,
#  'USD',
#  'USD',
#  'USD',
#  'USD',
#  None,
#  'EUR',
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  'USD',
#  'INR',
#  None,
#  None,
#  None,
#  'USD',
#  'INR',
#  None,
#  'USD',
#  None,
#  None,
#  'INR',
#  None,
#  'EUR',
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'FRF',
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  'GBP',
#  None,
#  None,
#  'EUR',
#  'EUR',
#  'INR',
#  None,
#  None,
#  'EUR',
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  'SEK',
#  None,
#  'EUR',
#  None,
#  None,
#  'BRL',
#  'USD',
#  'USD',
#  None,
#  None,
#  'EUR',
#  'ATS',
#  None,
#  None,
#  'USD',
#  None,
#  'USD',
#  None,
#  'EUR',
#  'USD',
#  None,
#  'USD',
#  None,
#  'USD',
#  'INR',
#  'EUR',
#  None,
#  'INR',
#  'INR',
#  'SEK',
#  'INR',
#  None,
#  None,
#  None,
#  'FIM',
#  None,
#  None,
#  None,
#  'USD',
#  'INR',
#  'INR',
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  None,
#  'USD',
#  'MXN',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  'EUR',
#  'EUR',
#  None,
#  None,
#  'INR',
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  'BRL',
#  'USD',
#  None,
#  None,
#  'USD',
#  None,
#  'USD',
#  'USD',
#  None,
#  None,
#  'INR',
#  None,
#  'INR',
#  None,
#  None,
#  'USD',
#  None,
#  'INR',
#  'USD',
#  None,
#  'CNY',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '',
#  None,
#  'INR',
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  'USD',
#  None,
#  'USD',
#  'USD',
#  'INR',
#  None,
#  None,
#  'INR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  'INR',
#  None,
#  'HKD',
#  None,
#  None,
#  'USD',
#  None,
#  'INR',
#  None,
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  'USD',
#  'CNY',
#  None,
#  None,
#  None,
#  None,
#  'CZK',
#  'INR',
#  'USD',
#  'USD',
#  'EUR',
#  'EUR',
#  None,
#  'INR',
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INR',
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  'USD',
#  None,
#  'NOK',
#  None,
#  None,
#  'EUR',
#  None,
#  'INR',
#  None,
#  'EUR',
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  'USD',
#  None,
#  None,
#  'CNY',
#  'CNY',
#  None,
#  None,
#  'USD',
#  'SGD',
#  None,
#  None,
#  'USD',
#  None,
#  'EUR',
#  'KRW',
#  'EUR',
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  'USD',
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  'EUR',
#  None,
#  None,
#  'USD',
#  None,
#  'KRW',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  'USD',
#  None,
#  'USD',
#  None,
#  'USD',
#  None,
#  'INR',
#  None,
#  None,
#  None,
#  'DKK',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  'USD',
#  None,
#  'DKK',
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  'BRL',
#  None,
#  'INR',
#  None,
#  None,
#  'INR',
#  'USD',
#  'KRW',
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  'EUR',
#  None,
#  'INR',
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  'USD',
#  None,
#  'USD',
#  'USD',
#  None,
#  None,
#  None,
#  'EUR',
#  'USD',
#  None,
#  None,
#  'NOK',
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  'EUR',
#  'USD',
#  None,
#  'USD',
#  None,
#  'EUR',
#  'EUR',
#  None,
#  None,
#  'USD',
#  None,
#  'INR',
#  'INR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'BRL',
#  None,
#  None,
#  'INR',
#  None,
#  None,
#  'AUD',
#  None,
#  'HUF',
#  None,
#  None,
#  'USD',
#  'EUR',
#  'EUR',
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  'USD',
#  'RUR',
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  'INR',
#  None,
#  'EUR',
#  None,
#  'EUR',
#  'NOK',
#  None,
#  'USD',
#  None,
#  None,
#  'INR',
#  None,
#  None,
#  'INR',
#  'CZK',
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  'USD',
#  'EUR',
#  'USD',
#  None,
#  'HUF',
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  'INR',
#  None,
#  'EUR',
#  'INR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'KRW',
#  None,
#  'USD',
#  None,
#  None,
#  'USD',
#  None,
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INR',
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  'INR',
#  None,
#  'HUF',
#  None,
#  None,
#  'CNY',
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  'USD',
#  None,
#  'EUR',
#  None,
#  None,
#  'USD',
#  None,
#  None,
#  'EUR',
#  'FRF',
#  None,
#  'INR',
#  'HKD',
#  None,
#  None,
#  'USD',
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  'EUR',
#  None,
#  None,
#  'USD',
#  'USD',
#  None,
#  None,
#  None,
#  'HKD',
#  None,
#  None,
#  'USD',
#  'USD',
#  'SEK',
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  'INR',
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  'EUR',
#  'EUR',
#  None,
#  None,
#  'EUR',
#  'USD',
#  None,
#  'MXN',
#  None,
#  'USD',
#  None,
#  'USD',
#  None,
#  None,
#  'EUR',
#  None,
#  'EUR',
#  'USD',
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  'DKK',
#  None,
#  'NOK',
#  None,
#  None,
#  None,
#  None,
#  'CNY',
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  'USD',
#  'USD',
#  None,
#  'USD',
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  'USD',
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  'EUR',
#  None,
#  'CNY',
#  None,
#  'EUR',
#  None,
#  'NOK',
#  'EUR',
#  'EUR',
#  'USD',
#  None,
#  'JPY',
#  'USD',
#  'USD',
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'FRF',
#  None,
#  None,
#  'EUR',
#  None,
#  'EUR',
#  None,
#  'USD',
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  'EUR',
#  None,
#  None,
#  'EUR',
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'THB',
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  None,
#  None,
#  'EUR',
#  'EUR',
#  None,
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  'EUR',
#  'EUR',
#  'EUR',
#  None,
#  None,
#  None,
#  None,
#  'USD',
#  None,
#  ...]

# %%
fl_movies_wbudget['currency'] = currency

# %%
budget_new = []
for budget in fl_movies_wbudget['budget']:
    if budget == None:
        budget_new.append(None)
    elif budget[0:1] == '$':
        budget_new.append(budget[1:])
    else:
        budget_new.append(budget[3:])

# %%
budget_new
# Out:
# ['31,000,000',
#  '11,400,000',
#  '19,000,000',
#  '10,000,000',
#  None,
#  '2,500,000,000',
#  '20,000,000',
#  None,
#  '7,000,000',
#  '2,000,000',
#  '7,450,000',
#  '200,000,000',
#  None,
#  '2,000,000',
#  '29,000,000',
#  '100,000,000',
#  None,
#  '25,000,000',
#  '9,500,000',
#  '13,000,000',
#  '19,000,000',
#  None,
#  '5,300,000',
#  None,
#  '14,000,000',
#  '10,000,000',
#  '4,000,000',
#  '3,300,000',
#  '3,400,000',
#  '500,000',
#  '8,900,000',
#  '38,600,000',
#  '45,000,000',
#  '56,600,000',
#  '2,000,000',
#  '13,430,000',
#  '7,000,000',
#  '11,700,000',
#  '23,000,000',
#  '48,000,000',
#  '1,800,000',
#  '18,000,000',
#  '12,000,000',
#  '20,470,000',
#  '13,500,000',
#  '4,200,000',
#  None,
#  None,
#  '5,000,000',
#  '4,000,000',
#  '1,390,000,000',
#  None,
#  '370,000,000',
#  '18,000,000',
#  '3,600,000',
#  '21,000,000',
#  '15,000,000',
#  '4,300,000',
#  None,
#  None,
#  '1,000,000',
#  '21,000,000',
#  None,
#  '1,000,000',
#  '450,000,000',
#  None,
#  None,
#  '5,420,000,000',
#  '1,100,000',
#  '4,800,000',
#  '12,000,000',
#  '4,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '2,200,000',
#  None,
#  '8,000,000',
#  None,
#  None,
#  '400,000,000',
#  None,
#  '700,000,000',
#  '60,720,000',
#  '100,000,000',
#  '10,000,000',
#  None,
#  None,
#  '3,000,000',
#  '327,000,000',
#  '550,000,000',
#  '3,300,000',
#  '8,000,000',
#  None,
#  None,
#  '3,300,000',
#  '3,000,000',
#  '3,500,000,000',
#  '7,395,080',
#  '9,200,000',
#  '5,300,000',
#  None,
#  None,
#  '300,000,000',
#  None,
#  None,
#  '1,500,000,000',
#  '30,100,000',
#  None,
#  '36,000,000',
#  None,
#  '10,000,000',
#  '4,500,000',
#  None,
#  '9,500,000',
#  None,
#  None,
#  None,
#  '450,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '20,000,000',
#  None,
#  '9,000,000',
#  None,
#  None,
#  None,
#  '1,500,000',
#  None,
#  None,
#  None,
#  '18,000,000',
#  '120,000,000',
#  '12,215,500,000',
#  '4,000,000',
#  '1,150,000,000',
#  None,
#  '11,700,000',
#  '1,000,000',
#  None,
#  '10,000,000,000',
#  None,
#  None,
#  None,
#  '5,300,000',
#  '10,000,000',
#  '150,000,000',
#  '13,000,000',
#  '5,500,000',
#  '220,000,000',
#  '6,800,000',
#  '15,400,000',
#  '8,000,000',
#  None,
#  None,
#  None,
#  '10,000,000,000',
#  None,
#  None,
#  '25,320,000',
#  None,
#  None,
#  '2,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '450,000,000',
#  '1,500,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '4,000,000',
#  '4,400,000',
#  None,
#  None,
#  None,
#  None,
#  '11,216,287',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '70,000,000',
#  None,
#  None,
#  None,
#  '16,600,000',
#  '4,300,000',
#  '4,200,000',
#  None,
#  None,
#  '1,350,000',
#  '3,000,000',
#  '49,000,000',
#  None,
#  '2,000,000',
#  '20,000,000',
#  '12,500,000',
#  '12,000,000',
#  None,
#  '7,000,000',
#  None,
#  '10,200,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '7,000,000',
#  '5,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '11,000,000',
#  '1,400,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '9,370,000',
#  None,
#  '46,000',
#  '750,000,000',
#  None,
#  None,
#  None,
#  '5,000,000',
#  '300,000,000',
#  None,
#  '7,980,000',
#  None,
#  None,
#  '700,000,000',
#  None,
#  '590,000',
#  '4,500,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '30,000,000',
#  None,
#  '12,800,000',
#  None,
#  None,
#  None,
#  '2,000,000',
#  None,
#  None,
#  '10,000,000',
#  '6,400,000',
#  '20,000,000',
#  None,
#  None,
#  '1,300,000',
#  '18,151,814',
#  None,
#  None,
#  None,
#  None,
#  '17,000,000',
#  None,
#  '5,300,000',
#  None,
#  None,
#  '16,000,000',
#  '4,000,000',
#  '30,000,000',
#  None,
#  None,
#  '2,000,000',
#  '70,000,000',
#  None,
#  None,
#  '12,000,000',
#  None,
#  '5,500,000',
#  None,
#  '1,467,000',
#  '3,000,000',
#  None,
#  '4,340,000',
#  None,
#  '10,920,000',
#  '35,000,000',
#  '4,300,000',
#  None,
#  '340,000,000',
#  '1,000,000',
#  '63,000,000',
#  '100,000,000',
#  None,
#  None,
#  None,
#  '8,000,000',
#  None,
#  None,
#  None,
#  '400,000',
#  '350,000,000',
#  '350,000,000',
#  None,
#  None,
#  '2,978,000',
#  None,
#  None,
#  None,
#  '63,300,000',
#  None,
#  None,
#  '6,000,000',
#  '37,700,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '1,490,641',
#  '2,500,000',
#  '1,300,000',
#  None,
#  None,
#  '120,000,000',
#  None,
#  None,
#  '2,600,000',
#  None,
#  None,
#  None,
#  None,
#  '3,000,000',
#  '6,000,000',
#  None,
#  None,
#  '6,250,000',
#  None,
#  '6,420,000',
#  '6,000,000',
#  None,
#  None,
#  '800,000,000',
#  None,
#  '450,000,000',
#  None,
#  None,
#  '4,500,000',
#  None,
#  '180,000,000',
#  '11,000,000',
#  None,
#  '400,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '',
#  None,
#  '550,000,000',
#  '7,000,000',
#  None,
#  None,
#  None,
#  None,
#  '68,005,000',
#  '16,000,000',
#  None,
#  '4,500,000',
#  '3,000,000',
#  '500,000,000',
#  None,
#  None,
#  '180,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '500,000',
#  None,
#  None,
#  '350,000,000',
#  None,
#  '60,000,000',
#  None,
#  None,
#  '9,000,000',
#  None,
#  '20,000,000',
#  None,
#  None,
#  '2,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '16,000,000',
#  '15,000,000',
#  '553,632,000',
#  None,
#  None,
#  None,
#  None,
#  '84,450,000',
#  '120,000,000',
#  '10,205,000',
#  '3,800,000',
#  '3,850,000',
#  '4,773,906',
#  None,
#  '100,000,000',
#  '6,789,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '102,000,000',
#  '430,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '5,000,000',
#  '5,000,000',
#  None,
#  '22,000,000',
#  None,
#  None,
#  '9,000,000',
#  None,
#  '350,000,000',
#  None,
#  '4,000,000',
#  None,
#  '8,620,000',
#  None,
#  None,
#  None,
#  '6,700,000',
#  None,
#  '9,000,000',
#  None,
#  None,
#  '300,000,000',
#  '100,000,000',
#  None,
#  None,
#  '4,600,000',
#  '4,500,000',
#  None,
#  None,
#  '1,800,000',
#  None,
#  '8,700,000',
#  '19,000,000,000',
#  '7,000,000',
#  None,
#  '1,300,000',
#  None,
#  None,
#  None,
#  '7,500,000',
#  '10,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '5,000,000',
#  '20,000,000',
#  None,
#  None,
#  '27,000,000',
#  None,
#  '15,000,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '3,000,000',
#  '13,000,000',
#  None,
#  '4,200,000',
#  None,
#  '8,000,000',
#  None,
#  '9,000,000',
#  None,
#  None,
#  None,
#  '35,500,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '4,750,000',
#  '2,000,000',
#  None,
#  '15,500,000',
#  None,
#  '21,400,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '200,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '5,000,000',
#  None,
#  '4,000,000',
#  None,
#  '260,000,000',
#  None,
#  None,
#  '200,000,000',
#  '65,000,000',
#  '1,300,000,000',
#  None,
#  '2,100,000',
#  None,
#  None,
#  None,
#  None,
#  '8,500,000',
#  None,
#  None,
#  '9,200,000',
#  None,
#  '200,000,000',
#  None,
#  None,
#  None,
#  '1,800,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '2,500,000',
#  None,
#  None,
#  None,
#  '2,000,000',
#  None,
#  '7,500,000',
#  None,
#  '12,500,000',
#  '3,500,000',
#  None,
#  None,
#  None,
#  '14,500,000',
#  '5,000,000',
#  None,
#  None,
#  '15,500,000',
#  None,
#  '33,000,000',
#  None,
#  None,
#  None,
#  '6,500,000',
#  '10,000,000',
#  None,
#  '1,400,000',
#  None,
#  '14,000,000',
#  '19,000,000',
#  None,
#  None,
#  '13,600,000',
#  None,
#  '200,000,000',
#  '290,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '3,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '2,500,000',
#  None,
#  None,
#  '530,000,000',
#  None,
#  None,
#  '2,200,000',
#  None,
#  '700,000,000',
#  None,
#  None,
#  '2,500,000',
#  '8,000,000',
#  '4,000,000',
#  None,
#  '21,166,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '10,000,000',
#  '4,770,000',
#  '6,000,000',
#  '3,300,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '7,870,000',
#  None,
#  '930,000,000',
#  None,
#  '5,000,000',
#  None,
#  '12,000,000',
#  '19,900,000',
#  None,
#  '7,500,000',
#  None,
#  None,
#  '550,000,000',
#  None,
#  None,
#  '200,000,000',
#  '36,000,000',
#  None,
#  '4,000,000',
#  None,
#  None,
#  None,
#  '1,000,000',
#  '5,700,000',
#  '1,900,000',
#  None,
#  '100,000,000',
#  None,
#  None,
#  None,
#  None,
#  '11,500,000',
#  None,
#  '400,000,000',
#  None,
#  '5,000,000',
#  '300,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '50,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '4,200,000,000',
#  None,
#  '38,000,000',
#  None,
#  None,
#  '9,000,000',
#  None,
#  None,
#  '25,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '60,000,000',
#  None,
#  None,
#  None,
#  '15,000,000',
#  None,
#  None,
#  None,
#  '800,000',
#  None,
#  '150,000,000',
#  None,
#  '2,500,000,000',
#  None,
#  None,
#  '30,000,000',
#  None,
#  '26,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '2,500,000',
#  '73,000,000',
#  None,
#  '960,000',
#  None,
#  None,
#  '15,000,000',
#  None,
#  None,
#  '1,600,000',
#  '25,000,000',
#  None,
#  '200,000,000',
#  '300',
#  None,
#  None,
#  '2,500',
#  '13,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '6,000,000',
#  '8,900,000',
#  None,
#  None,
#  '10,000,000',
#  '7,600,000',
#  None,
#  None,
#  None,
#  '40,000,000',
#  None,
#  None,
#  '35,000,000',
#  '6,428,966',
#  '9,000,000',
#  None,
#  None,
#  None,
#  None,
#  '7,300,000',
#  None,
#  None,
#  '400,000,000',
#  None,
#  '26,400,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '3,000,000',
#  None,
#  None,
#  None,
#  '2,150,000',
#  '6,000,000',
#  None,
#  None,
#  '4,000,000',
#  '1,500,000',
#  None,
#  '25,000,000',
#  None,
#  '4,000,000',
#  None,
#  '3,500,000',
#  None,
#  None,
#  '8,000,000',
#  None,
#  '2,000,000',
#  '20,000,000',
#  '2,000,000',
#  None,
#  None,
#  None,
#  None,
#  '300,000',
#  None,
#  None,
#  '1,750,000',
#  None,
#  None,
#  None,
#  '45,000,000',
#  None,
#  '47,500,000',
#  None,
#  None,
#  None,
#  None,
#  '10,000,000',
#  None,
#  '600,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '9,980,000',
#  None,
#  '23,000,000',
#  '2,000,000',
#  None,
#  '18,000,000',
#  '12,800,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '1,000,000',
#  '25,000,000',
#  None,
#  None,
#  None,
#  '40,000,000',
#  None,
#  '5,250,784',
#  None,
#  '100,000,000',
#  None,
#  '8,555,500',
#  None,
#  '17,500,000',
#  '9,500,000',
#  '5,383,899',
#  '4,000,000',
#  None,
#  '234,000,000',
#  '5,000,000',
#  '5,000,000',
#  None,
#  None,
#  None,
#  '12,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '650,000,000',
#  None,
#  None,
#  '12,000,000',
#  None,
#  '4,000,000',
#  None,
#  '12,000,000',
#  None,
#  '500,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '50,000,000',
#  '7,209,690',
#  None,
#  None,
#  '2,000,000',
#  None,
#  '300,000',
#  None,
#  None,
#  None,
#  '2,500,000',
#  None,
#  None,
#  None,
#  None,
#  '5,800,000',
#  None,
#  None,
#  '1,250,000',
#  None,
#  None,
#  None,
#  '15,000,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '300,000,000',
#  None,
#  '12,700,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '2,300,000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '5,000,000',
#  None,
#  None,
#  None,
#  '15,300,000',
#  '850,000',
#  None,
#  '20,000,000',
#  None,
#  None,
#  None,
#  None,
#  '1,605,000',
#  '2,700,000',
#  '3,600,000',
#  None,
#  None,
#  None,
#  None,
#  '300,000',
#  None,
#  ...]

# %%
len(budget_new)
# Out:
# 1659

# %%
fl_movies_wbudget['budget_new'] = budget_new

# %%
fl_movies_wbudget['budget_new'] = fl_movies_wbudget['budget_new'].str.replace(",","")

# %%
fl_movies_wbudget.loc[fl_movies_wbudget['budget_new'] == '', 'budget_new'] = None

# %%
fl_movies_wbudget['budget_new'] = fl_movies_wbudget['budget_new'].astype(float)

# %%
fl_movies_wbudget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1659 entries, 0 to 1658
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   title                                     1659 non-null   object
#  1   lifetime_gross                            1659 non-null   float64
#  2   max_theaters                              1651 non-null   float64
#  3   domestic_opening                          1591 non-null   float64
#  4   num_opening_theaters                      1593 non-null   float64
#  5   release_date                              1659 non-null   datetime64[ns]
#  6   domestic_distributor                      1659 non-null   object
#  7   domestic_total_gross                      1659 non-null   float64
#  8   international_total_gross                 1659 non-null   float64
#  9   earliest_release_location                 1659 non-null   object
#  10  runtime                                   1612 non-null   float64
#  11  genres                                    1659 non-null   object
#  12  crew                                      1659 non-null   object
#  13  cast                                      1659 non-null   object
#  14  earliest_release_location_opening_gross   1524 non-null   float64
#  15  earliest_release_location_original_gross  1653 non-null   float64
#  16  language                                  1657 non-null   object
#  17  budget                                    578 non-null    object
#  18  currency                                  578 non-null    object
#  19  budget_new                                577 non-null    float64
# dtypes: datetime64[ns](1), float64(10), object(9)
# memory usage: 336.7+ KB

# %%
import pickle #immediately pickling dataframe
fl_movies_wbudget.to_pickle('fl_movies_wbudget.pickle')

# %%
fl_movies_wbudget = pd.read_pickle('fl_movies_wbudget.pickle')

# %% [markdown]
# Attempting to convert currencies

# %% [markdown]
# https://stackoverflow.com/questions/45660529/forex-python-in-custom-function-for-pandas-dataframe
# https://stackoverflow.com/questions/50114132/python-pandas-creating-a-new-column-using-currency-converter

# %%
'''from forex_python.converter import CurrencyRates
c = CurrencyRates()
import numpy as np
from datetime import datetime, timedelta
from time import sleep
    
def try_convert(amount, currency, date1):
    try:
        res = c.convert(base_cur=currency,dest_cur='USD',amount=amount, date_obj=date1)
    except:
        res = 'Could Not Convert'
    return res

def convert_rates(amount,currency,date1):
    if currency == None:
        return None 
    elif currency != 'USD':
        return try_convert(amount, currency, date1)
    else:
        return amount '''

# %%
'''from forex_python.converter import CurrencyRates
c = CurrencyRates()
import numpy as np
from datetime import datetime, timedelta
from time import sleep
    

def convert_rates(amount,currency,date1):
    if currency == None:
        return None 
    elif currency != 'USD':
        return c.convert(base_cur=currency,dest_cur='USD',amount=amount, date_obj=date1)
    else:
        return amount'''

# %%
#fl_movies_wbudget['budget_usd'] = np.vectorize(convert_rates)(amount=fl_movies_wbudget['budget_new'],currency=fl_movies_wbudget['currency'],date1=fl_movies_wbudget['release_date'])

# %%
#c = CurrencyConverter() 

#def currency_convertor(row, new_currency):
    #amount = row['budget']
    #curr = row['currency']
    #date_r = row['release_date']
    #new_curr = c.convert(amount,curr,new_currency,date=date(date_r))
    #return new_curr

#fl_movies_wbudget['new_budget'] = fl_movies_wbudget.apply(lambda x: currency_convertor(x,new_currency="USD"), axis=1)

# %%
# !pip install tqdm
from tqdm import tqdm

def converter(base_currency, amount_):
    c = CurrencyRates()
    converted_values = []
    bad_rows = []
    for i in tqdm(range(len(base_currency))):
        if base_currency[i] == 'USD':
            converted_values.append(amount_[i])
        else:
            try:
                value = c.convert(base_cur = base_currency[i], amount = amount_[i], dest_cur = 'USD')
                converted_values.append(value)
            except:
                bad_rows.append(i)
                converted_values.append('Failed to convert.')
    return converted_values

x = fl_movies_wbudget['currency'].values
y = fl_movies_wbudget['budget_new'].values

usd_budget = converter(x,y)

fl_movies_wbudget['budget_usd'] = usd_budget
# Out:
# Requirement already satisfied: tqdm in ./opt/anaconda3/envs/metis/lib/python3.8/site-packages (4.60.0)
# 100%|██████████| 1659/1659 [02:45<00:00, 10.02it/s]

# %%
import pickle #immediately pickling dataframe
fl_movies_wbudget.to_pickle('fl_movies_wbudget.pickle')

# %%
fl_movies_wbudget.head()
# Out:
#              title  lifetime_gross  max_theaters  domestic_opening  \
# 0             Hero      53710019.0        2175.0        17800000.0
# 1         Parasite      53369749.0        2001.0          393216.0
# 2  Pan's Labyrinth      37634615.0        1143.0          568641.0
# 3           Amélie      33225499.0         303.0          136470.0
# 4         Fearless      24633730.0        1810.0        10564000.0
#
#    num_opening_theaters release_date domestic_distributor  \
# 0                2031.0   2004-08-27              Miramax
# 1                   3.0   2019-10-11                 Neon
# 2                  17.0   2006-12-29         Picturehouse
# 3                   3.0   2001-11-02              Miramax
# 4                1806.0   2006-09-22       Rogue Pictures
#
#    domestic_total_gross  international_total_gross earliest_release_location  \
# 0            53710019.0                123685538.0               APAC, China
# 1            53369749.0                205484917.0               South Korea
# 2            37634615.0                 46215652.0                     Spain
# 3            33225499.0                140699243.0                    France
# 4            24633730.0                 43439118.0               APAC, China
#
#    ...                        genres  \
# 0  ...      Action Adventure History
# 1  ...         Comedy Drama Thriller
# 2  ...             Drama Fantasy War
# 3  ...                Comedy Romance
# 4  ...  Action Biography Drama Sport
#
#                                                 crew  \
# 0  Yimou Zhang Director, Feng Li Writer, Yimou Zh...
# 1  Bong Joon Ho Director, Bong Joon Ho Writer, Bo...
# 2  Guillermo del Toro Director, Guillermo del Tor...
# 3  Jean-Pierre Jeunet Director, Guillaume Laurant...
# 4  Ronny Yu Director, Chris Chow Writer, Richard ...
#
#                                                 cast  \
# 0  Jet Li, Tony Chiu-Wai Leung, Maggie Cheung, Zi...
# 1  Kang-ho Song, Sun-kyun Lee, Yeo-jeong Cho, Woo...
# 2  Ivana Baquero, Ariadna Gil, Sergi López, Marib...
# 3  Audrey Tautou, Mathieu Kassovitz, Rufus, Lorel...
# 4                  Jet Li, Li Sun, Yong Dong, Yun Qu
#
#   earliest_release_location_opening_gross  \
# 0                              17800000.0
# 1                                393216.0
# 2                                568641.0
# 3                                136470.0
# 4                              10564000.0
#
#    earliest_release_location_original_gross  language       budget currency  \
# 0                                53710019.0  Mandarin  $31,000,000      USD
# 1                                53369749.0    Korean  $11,400,000      USD
# 2                                37634615.0   Spanish  $19,000,000      USD
# 3                                33225499.0    French  $10,000,000      USD
# 4                                24633730.0  Mandarin         None     None
#
#    budget_new  budget_usd
# 0  31000000.0  31000000.0
# 1  11400000.0  11400000.0
# 2  19000000.0  19000000.0
# 3  10000000.0  10000000.0
# 4         NaN         NaN
#
# [5 rows x 21 columns]

# %%
import pandas as pd

my_dict = {key:value,key:value,key:value,...}
df = pd.DataFrame(list(my_dict.items()),columns = ['column1','column2'])

# %%
fl_movies_wbudget[fl_movies_wbudget['budget'].isna()].title[19:40]
# Out:
# 77     Portrait of a Lady on Fire
# 79                 Mission Mangal
# 81                   Om Shanti Om
# 82               A Man Called Ove
# 84                    Shoplifters
# 89                        Phoenix
# 90         I've Loved You So Long
# 96               The Band's Visit
# 97                         Bharat
# 104              Monsieur Ibrahim
# 105             My Brother's Wife
# 107          In the Mood for Love
# 108                      RamLeela
# 111                 Walk on Water
# 113              Bharath Ane Nenu
# 116                 Kapoor & Sons
# 118                     Bang Bang
# 119              Man on the Train
# 120          Do It Like An Hombre
# 122                          Kick
# 123                  Love Aaj Kal
# Name: title, dtype: object

# %%
# Create DataFrame
other_budgets_df = pd.DataFrame(data)

# %%
other_budgets = {'title': ['Padmaavat','PK','Dhoom 3','Biutiful',
                           'Pain and Glory','Ong-Bak: The Thai Warrior','Ae Dil Hai Mushkil','With a Friend Like Harry...',
                           'Yeh Jawaani Hai Deewani','Ida','The Class','Portrait of a Lady on Fire',
                          'Om Shanti Om','A Man Called Ove', 'Shoplifters', 'Phoenix']
                           
                'budget_USD':['30000000','12000000','30000000','35000000',
                              '10800000','1100000','15000000','3000000',
                              '8300000','2600000','3700000', '5400000',
                             '7000000', '300000', '110000000', '']}

  
# Create DataFrame
other_budgets_df = pd.DataFrame(other_budgets)
