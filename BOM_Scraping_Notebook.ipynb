# %% [markdown]
# # Box Office Mojo - Scraping

# %% [markdown]
# Importing packages and opening chromedriver

# %%
from bs4 import BeautifulSoup
import requests
import time, os
import re
import pandas as pd
import time

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %% [markdown]
# ### Getting table data for foreign language movies from main page

# %% [markdown]
# Getting list of foreign language movies main page urls

# %%
url_list = []
list_ranges = [100*i for i in range(25)]
for range_ in list_ranges:
    url_ = "https://www.boxofficemojo.com/genre/sg4208980225/?offset={}".format(range_)
    url_list.append(url_)

# %% [markdown]
# Getting table data from each page

# %%
movies = {}
for url in url_list: 
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")
    
    #finding the main table and its rows 
    table = soup.find('table') #finding the main table 
    rows = table.find_all('tr') #finding the rows - tr tag is for rows
    
    #grabbing data for 100 movies with a loop and adding to a dictionary
    for row in rows[1:]:
        items = row.find_all('td')
        link = items[1].find('a')
        title, url = link.text, link['href']
        if title not in movies.keys(): #some movies appear twice 
            movies[title] = [url] + [i.text for i in items] 
        else:
            movies[title+"_2"] = [url] + [i.text for i in items]

# %% [markdown]
# Putting table data for foreign language movies in a dataframe

# %%
fl_movies = pd.DataFrame(movies).T  #transpose
fl_movies.columns = ['link_stub', 'gross_rank', 'title',
                    'lifetime_gross', 'max_theaters', 'domestic_opening', 
                     'num_opening_theaters', 'release_date', 'domestic_distributor']

# %% [markdown]
# Looking at duplicate movie titles

# %%
for movie in movies.keys():
    if movie[-2:] == "_2":
        print(movie)
# Out:
# The Promise_2
# Fireworks_2
# Brothers_2
# Stalingrad_2
# The Big Picture_2
# Three_2
# Django_2
# Clash_2
# Gloria_2
# Come Undone_2
# Marius_2
# Fanny_2
# Gabrielle_2
# The Family_2
# Iceman_2

# %% [markdown]
# ### Getting table data for foreign language movies from individual movie pages

# %% [markdown]
# Function to grab values

# %%
def get_movie_value(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find(text=re.compile(field_name))
    
    if not obj: 
        return None
    
    # this works for most of the values
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text 
    else:
        return None

# %% [markdown]
# Helper functions to parse strings into appropriate data types

# %%
import dateutil.parser

def money_to_int(moneystring):
    moneystring = moneystring.replace('$', '').replace(',', '')
    return int(moneystring)

def runtime_to_minutes(runtimestring):
    runtime = runtimestring.split()
    try:
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

# %% [markdown]
# Creating a function to get features from individual pages and put them in a dictionary

# %%
def get_movie_dict(link):
    base_url = 'https://www.boxofficemojo.com'
    
    #Create full url to scrape
    url = base_url + link
    
    #Request HTML and parse
    for i in range(5): 
        try:
            response = requests.get(url)
        except:
            time.sleep(10) 
            continue
        else:
            break
    page = response.text
    soup = BeautifulSoup(page,"lxml")

    
    headers = ['title', 
               'domestic_total_gross', 
               'international_total_gross',
               'domestic_distributor',
               'domestic_opening',
                'budget',
                'release_date',
                 'release_location',
                 'rating',
                'runtime', 
               'genres',
                'original_release_markets_num',
                 'crew',
                  'cast',
              'earliest_release_location_opening_gross',
               'earliest_release_location_original_gross']
    
    #Get title
    title_string = soup.find('title').text
    title = title_string.split('- Box Office Mojo')[0].strip()

    #Get domestic gross
    try:
        raw_domestic_total_gross = (soup.find(class_='mojo-performance-summary-table')
                                    .find_all('span', class_='money')[0]
                                    .text
                               )
        domestic_total_gross = money_to_int(raw_domestic_total_gross)
    except:
        domestic_total_gross = None 
    
    #Get international gross
    try:
        raw_international_total_gross = (soup.find(class_='mojo-performance-summary-table')
                                    .find_all('span', class_='money')[1]
                                    .text
                               )
        international_total_gross = money_to_int(raw_international_total_gross)
    except:
        international_total_gross = None
    
    #Get domestic distributor
    try:
        domestic_distributor = get_movie_value(soup,'Domestic Distributor')
        domestic_distributor = domestic_distributor.replace('See full company information', '') # Removing extra descrip
        domestic_distributor = domestic_distributor.strip()
    except:
        domestic_distributor = None 

    #Get domestic opening revenue 
    try:
        raw_domestic_opening = get_movie_value(soup,'Domestic Opening')
        domestic_opening = money_to_int(raw_domestic_opening)
    except:
        domestic_opening = None 
    
    #Get budget
    try:
        raw_budget = get_movie_value(soup,'Budget')
        budget = money_to_int(raw_budget)
    except:
        budget = None 

    #Get release date
    try:
        raw_release_date = get_movie_value(soup,'Release Date').split('\n')[0]
        release_date = to_date(raw_release_date)
    except:
        release_date = None 
    
    #Get earliest release location
    try:
        release_location = get_movie_value(soup,'Release Date').split('\n')[1].strip().strip(')').strip('(')
    except:
        release_location = None 
        
    #Get rating
    try:
        rating = get_movie_value(soup,'MPAA')
    except:
        rating = None
    
    #Get runtime
    try:
        raw_runtime = get_movie_value(soup,'Running')
        runtime = runtime_to_minutes(raw_runtime)
    except:
        runtime = None 
    
    #Get genres
    try:
        genres = get_movie_value(soup,'Genres')
        genres = genres.replace('\n', '')
        _RE_COMBINE_WHITESPACE = re.compile(r"\s+")
        genres = _RE_COMBINE_WHITESPACE.sub(" ", genres).strip()
    except: 
        genres = None 
    
    #Get original release number of markets 
    try:
        original_release_markets_num = soup.find(class_='a-bordered a-horizontal-stripes a-size-base-plus').find_all('td', class_='a-align-center')[2].text
        original_release_markets_num = original_release_markets_num.replace('markets', '').strip()
    except:
        original_release_markets_num = None 
       
    #OPENING CHROME DRIVER 
    driver = webdriver.Chrome(chromedriver)
    for i in range(5): #Try 5 times to reach page
        try:
            driver.get(url)
        except:
            time.sleep(10) # wait 10 seconds and then make http request again
            continue
        else:
            break
    
    #CLICKING ON CAST AND CREW TAB      
    for i in range(5): #Try 5 times to click tab
        try:
            cast_and_crew = driver.find_element_by_xpath('//*[@id="tabs"]/div/a[2]')
            cast_and_crew.click()
        except:
            time.sleep(5) # wait 5 seconds and then make http request again
            driver.refresh() # refresh page
            continue
        else:
            break
    
    #Get crew
    try:
        raw_crew = driver.find_element_by_xpath('//*[@id="principalCrew"]/tbody')
        crew = raw_crew.text.replace('Crew Member Role\n', '').replace('\n', ', ')
    except: 
        crew = None
    
    #Get cast
    try: 
        raw_cast = driver.find_element_by_xpath('//*[@id="principalCast"]')
        string_cast = raw_cast.text
        list_cast = string_cast.split('\n')[1::2]
        cast = ",".join(list_cast).replace(',',', ')
    except:
        cast = None 
    
    #CLICKING ON RELEASE GROUP DROPDOWN AND SELECTING ORIGINAL
    for i in range(5): #Try 5 times to click dropdown
        try:
            all_releases_dropdown = driver.find_element_by_xpath('//*[@id="releasegroup-picker-navSelector"]')
            all_releases_dropdown.send_keys("Original Release")
        except:
            time.sleep(5) # wait 5 seconds and then make request again
            driver.refresh() # refresh page
            continue
        else:
            break
    
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    table_dates = []
    tables = soup.find_all('table', class_="a-bordered a-horizontal-stripes mojo-table releases-by-region")
    for table in tables:
        rows = table.find_all('tr')
        for row in rows:
            data = row.find_all('td')
            if len(data) != 0:
                table_dates.append(data)
    new_list = []
    for list_ in table_dates:
        list_row = []
        for element in list_:
            if element.text == '\n        –\n    ':
                list_row.append('missing')
            elif element.text == '':
                list_row.append('missing')
            else: 
                list_row.append(element.text)
        new_list.append(list_row)

    original_release_df = pd.DataFrame(new_list, columns=['country','release_date','opening_revenue','gross_revenue'])
    original_release_df['release_date'].replace({"missing": "Jan 1, 2022"}, inplace=True)
    original_release_df['release_date'] = pd.to_datetime(original_release_df['release_date'], format='%b %d, %Y')
    original_release_df = original_release_df.sort_values(by="release_date")
    original_release_df.reset_index(drop=True)
    
    #Get earliest release location opening revenue
    try:
        raw_earliest_release_location_opening = original_release_df.opening_revenue[0]
        earliest_release_location_opening_gross = money_to_int(raw_earliest_release_location_opening)
    except:
        earliest_release_location_opening_gross = None 
    
    #Get earliest release location gross revenue
    try:
        raw_earliest_release_location_total_gross = original_release_df.gross_revenue[0]
        earliest_release_location_original_gross = money_to_int(raw_earliest_release_location_total_gross)
    except: 
        earliest_release_location_original_gross = None 
    
    #QUITTING CHROME DRIVER
    driver.quit()


    #Create movie dictionary and return
    movie_dict = dict(zip(headers, [title,
                                domestic_total_gross, 
                                international_total_gross,
                                domestic_distributor,
                                domestic_opening,
                                budget,
                                release_date,
                                release_location,
                                rating,
                                runtime, 
                                genres,
                                original_release_markets_num,
                                crew,
                                cast,
                                earliest_release_location_opening_gross,
                                earliest_release_location_original_gross]))

    return movie_dict

# %% [markdown]
# Passing each link stub into the function

# %%
fl_movies_page_info_list = [] #saving the info to a dictionary OUTSIDE the function

for link in fl_movies.link_stub:
    fl_movies_page_info_list.append(get_movie_dict(link))
    
fl_movies_page_info = pd.DataFrame(fl_movies_page_info_list)  #converting list of dict to df
fl_movies_page_info.set_index('title', inplace=True) 

import pickle #immediately pickling dataframe
fl_movies_page_info.to_pickle('fl_movies_page_info.pickle')

# %%
fl_movies_page_info = pd.read_pickle('fl_movies_page_info.pickle')

# %% [markdown]
# Converting list of dictionaries into a dataframe

# %%
fl_movies_page_info.shape
# Out:
# (2499, 15)

# %% [markdown]
# Replacing titles where movies share the same title

# %%
fl_movies_page_info.index = fl_movies_page_info.index.where(~fl_movies_page_info.index.duplicated(), fl_movies_page_info.index + '_2')

# %%
fl_movies.head()
# Out:
#                                                            link_stub  \
# Crouching Tiger, Hidden Dragon  /title/tt0190332/?ref_=bo_ge_table_1
# Life Is Beautiful               /title/tt0118799/?ref_=bo_ge_table_2
# Hero                            /title/tt0299977/?ref_=bo_ge_table_3
# Parasite                        /title/tt6751668/?ref_=bo_ge_table_4
# Instructions Not Included       /title/tt2378281/?ref_=bo_ge_table_5
#
#                                gross_rank                           title  \
# Crouching Tiger, Hidden Dragon          1  Crouching Tiger, Hidden Dragon
# Life Is Beautiful                       2               Life Is Beautiful
# Hero                                    3                            Hero
# Parasite                                4                        Parasite
# Instructions Not Included               5       Instructions Not Included
#
#                                lifetime_gross max_theaters domestic_opening  \
# Crouching Tiger, Hidden Dragon   $128,078,872        2,027         $663,205
# Life Is Beautiful                 $57,247,384        1,136         $118,920
# Hero                              $53,710,019        2,175      $17,800,000
# Parasite                          $53,369,749        2,001         $393,216
# Instructions Not Included         $44,467,206          978       $7,846,426
#
#                                num_opening_theaters  release_date  \
# Crouching Tiger, Hidden Dragon                   16   Dec 8, 2000
# Life Is Beautiful                                 6  Oct 23, 1998
# Hero                                          2,031  Aug 27, 2004
# Parasite                                          3  Oct 11, 2019
# Instructions Not Included                       348  Aug 30, 2013
#
#                                       domestic_distributor
# Crouching Tiger, Hidden Dragon  Sony Pictures Classics\n\n
# Life Is Beautiful                              Miramax\n\n
# Hero                                           Miramax\n\n
# Parasite                                          Neon\n\n
# Instructions Not Included                    Lionsgate\n\n

# %%
fl_movies_page_info.shape
# Out:
# (2499, 15)

# %% [markdown]
# Finding different indices for the two dataframes created

# %%
different_indices = fl_movies[~fl_movies.index.isin(fl_movies_page_info.index)]
different_indices
# Out:
#                                                                                  link_stub  \
# Padmaavat                                            /title/tt5935704/?ref_=bo_ge_table_23
# Huevos: Little Rooster's Egg-cellent Adventure       /title/tt4643580/?ref_=bo_ge_table_38
# Central Station                                      /title/tt0140888/?ref_=bo_ge_table_69
# Bad Education                                        /title/tt0275491/?ref_=bo_ge_table_85
# Ong-Bak: The Thai Warrior                            /title/tt0368909/?ref_=bo_ge_table_99
# Entre Nous                                           /title/tt0085370/?ref_=bo_ge_table_20
# La veuve de Saint-Pierre                             /title/tt0191636/?ref_=bo_ge_table_53
# Veer-Zaara                                           /title/tt0420332/?ref_=bo_ge_table_68
# Dans une galaxie près de chez vous - Le film         /title/tt0385635/?ref_=bo_ge_table_27
# The Chorus                                           /title/tt0372824/?ref_=bo_ge_table_53
# Hum Saath-Saath Hain: We Stand United                /title/tt0216817/?ref_=bo_ge_table_70
# Salaam-E-Ishq                                        /title/tt0485272/?ref_=bo_ge_table_95
# Kon-Tiki                                             /title/tt1613750/?ref_=bo_ge_table_45
# Under the Sand                                       /title/tt0240913/?ref_=bo_ge_table_57
# Dans une galaxie près de chez vous - Le film           $2,259,688
# The Chorus                                             $2,087,128
# Hum Saath-Saath Hain: We Stand United                  $2,005,094
# Salaam-E-Ishq                                          $1,852,050
# Kon-Tiki                                               $1,517,410
# Under the Sand                                         $1,452,698
# The Last Kiss                                          $1,048,950
# Xiu Xiu: The Sent-Down Girl                            $1,010,933
# Baar Baar Dekho                                          $981,947
# The 100 Year-Old Man Who Climbed Out the Window...       $944,193
# Delhi-6                                                  $879,913
# The Ex-File 3: The Return of The Exes                    $838,959
# Burning                                                  $718,991
# Non-Fiction                                              $704,919
# Mid-August Lunch                                         $675,299
# Jaan-E-Mann: Let's Fall in Love... Again                 $650,000
# Teo-neol                                                 $568,876
# Changing Times                                           $545,255
# Queen to Play                                            $478,710
# Luck-Key                                                 $466,505
# Head-On                                                  $435,395
# Baise-moi                                                $420,224
# Ju-on: The Grudge                                        $325,680
# Anonyma - Eine Frau in Berlin                            $294,014
# 3-Iron                                                   $241,914
# Angel-A                                                  $202,647
# Live-In Maid                                             $200,433
# Lilya 4-Ever                                             $184,023
# Grand Illusion                                           $174,065
# Mughal-E-Azam                                            $161,434
# 3-D Sex and Zen: Extreme Ecstasy                         $153,215
# Shortkut - The Con Is On                                 $100,304
# Tazza: One-Eyed Jack                                      $97,655
# I Married an Anti-Fan                                     $89,408
# Hara-Kiri: Death of a Samurai                             $75,688
# Cet amour-là                                              $72,844
# By the Grace of God                                       $67,059
# Exiled                                                    $51,957
# Fagara                                                    $43,417
# Britt-Marie Was Here                                      $36,549
# Love in Space                                             $34,787
# All About Lily Chou-Chou                                  $26,485
# Brodeuses - A Common Thread                               $26,042
# Haikara-San: Here Comes Miss Modern                       $16,572
# Ong-bak 3                                                 $14,890
# The Devil's Miner                                         $14,289
# Post Mortem                                                $9,750
# 12 Days                                                    $5,204
# Arabian Nights: Volume 3 - The Enchanted One               $4,502
# The Family_2                                               $3,696
# Demi-soeur                                                   $943
#
#                                                    max_theaters  \
# Padmaavat                                                   354
# Huevos: Little Rooster's Egg-cellent Adventure              616
# Central Station                                             144
# Bad Education                                               106
# Ong-Bak: The Thai Warrior                                   387
# Entre Nous                                                    -
# La veuve de Saint-Pierre                                     83
# Veer-Zaara                                                   88
# Dans une galaxie près de chez vous - Le film                 74
# The Chorus                                                   34
# Hum Saath-Saath Hain: We Stand United                        69
# Salaam-E-Ishq                                                86
# Kon-Tiki                                                     75
# Under the Sand                                               25
# The Last Kiss                                                31
# Xiu Xiu: The Sent-Down Girl                                  22
# Baar Baar Dekho                                             146
# The 100 Year-Old Man Who Climbed Out the Window...           76
# Delhi-6                                                      90
# The Ex-File 3: The Return of The Exes                        24
# Burning                                                      27
# Non-Fiction                                                  89
# Mid-August Lunch                                             23
# Jaan-E-Mann: Let's Fall in Love... Again                     73
# Teo-neol                                                     36
# Changing Times                                                7
# Queen to Play                                                18
# Luck-Key                                                     26
# Head-On                                                       9
# Baise-moi                                                     5
# Ju-on: The Grudge                                            11
# Delhi-6                                                      UTV Motion Pictures\n\n
# The Ex-File 3: The Return of The Exes               China Lion Film Distribution\n\n
# Burning                                                Well Go USA Entertainment\n\n
# Non-Fiction                                                            IFC Films\n\n
# Mid-August Lunch                                                 Zeitgeist Films\n\n
# Jaan-E-Mann: Let's Fall in Love... Again                            Adlabs Films\n\n
# Teo-neol                                               Well Go USA Entertainment\n\n
# Changing Times                                                 Koch Lorber Films\n\n
# Queen to Play                                                    Zeitgeist Films\n\n
# Luck-Key                                                            JBG Pictures\n\n
# Head-On                                                         Strand Releasing\n\n
# Baise-moi                                                         WinStar Cinema\n\n
# Ju-on: The Grudge                                                Vitagraph Films\n\n
# Anonyma - Eine Frau in Berlin                                   Strand Releasing\n\n
# 3-Iron                                                    Sony Pictures Classics\n\n
# Angel-A                                                   Sony Pictures Classics\n\n
# Live-In Maid                                                                       -
# Lilya 4-Ever                                                     Newmarket Films\n\n
# Grand Illusion                                                   Rialto Pictures\n\n
# Mughal-E-Azam                                                UTV Motion Pictures\n\n
# 3-D Sex and Zen: Extreme Ecstasy                    China Lion Film Distribution\n\n
# Shortkut - The Con Is On                                               Studio 18\n\n
# Tazza: One-Eyed Jack                                   Well Go USA Entertainment\n\n
# I Married an Anti-Fan                               China Lion Film Distribution\n\n
# Hara-Kiri: Death of a Samurai                                       Tribeca Film\n\n
# Cet amour-là                                                    New Yorker Films\n\n
# By the Grace of God                                              Music Box Films\n\n
# Exiled                                                         Magnolia Pictures\n\n
# Fagara                                              China Lion Film Distribution\n\n
# Britt-Marie Was Here                                           Cohen Media Group\n\n
# Love in Space                                       China Lion Film Distribution\n\n
# All About Lily Chou-Chou                                         Cowboy Pictures\n\n
# Brodeuses - A Common Thread                                     New Yorker Films\n\n
# Haikara-San: Here Comes Miss Modern                                  Eleven Arts\n\n
# Ong-bak 3                                                      Magnolia Pictures\n\n
# The Devil's Miner                                                      First Run\n\n
# Post Mortem                                                          Kino Lorber\n\n
# 12 Days                                                            Distrib Films\n\n
# Arabian Nights: Volume 3 - The Enchanted One                         Kino Lorber\n\n
# The Family_2                                                       Film Movement\n\n
# Demi-soeur                                                       Rialto Pictures\n\n

# %%
fl_movies_page_info_list_2 = [] #saving the info to a dictionary OUTSIDE the function

for link in different_indices.link_stub:
    fl_movies_page_info_list_2.append(get_movie_dict(link))
    
fl_movies_page_info_2 = pd.DataFrame(fl_movies_page_info_list_2)  #converting list of dict to df
fl_movies_page_info_2.set_index('title', inplace=True)

# %%
fl_movies_page_info_2.head()
# Out:
#                                                 domestic_total_gross  \
# title
# Padmaavat                                                   11846060
# Huevos: Little Rooster's Egg-cellent Adventure               9080818
# Central Station                                              5969553
# Bad Education                                                5284284
# Ong-Bak: The Thai Warrior                                    4563167
#
#                                                 international_total_gross  \
# title
# Padmaavat                                                        48662720
# Huevos: Little Rooster's Egg-cellent Adventure                   16811743
# Central Station                                                      1520
# Bad Education                                                    35138995
# Ong-Bak: The Thai Warrior                                        15672259
#
#                                                   domestic_distributor  \
# title
# Padmaavat                                                Viva Pictures
# Huevos: Little Rooster's Egg-cellent Adventure               Lionsgate
# Central Station                                 Sony Pictures Classics
# Bad Education                                   Sony Pictures Classics
# Ong-Bak: The Thai Warrior                            Magnolia Pictures
#
#                                                 domestic_opening     budget  \
# title
# Padmaavat                                              4493384.0        NaN
# Huevos: Little Rooster's Egg-cellent Adventure         3424702.0  5300000.0
# Central Station                                          35708.0        NaN
# Bad Education                                           147370.0  5000000.0
# Ong-Bak: The Thai Warrior                              1334869.0        NaN
#
#                                                release_date release_location  \
# title
# Padmaavat                                        2018-01-25        5 markets
# Huevos: Little Rooster's Egg-cellent Adventure   2015-08-20            LATAM
# Central Station                                  1998-11-20         Domestic
# Bad Education                                    2004-03-19            Spain
# Ong-Bak: The Thai Warrior                        2003-08-13           Taiwan
#
#                                                rating  runtime  \
# title
# Padmaavat                                        None    164.0
# Huevos: Little Rooster's Egg-cellent Adventure  PG-13     98.0
# Central Station                                     R    110.0
# Bad Education                                   NC-17    106.0
# Ong-Bak: The Thai Warrior                           R    108.0
#
#                                                                                    genres  \
# title
# Padmaavat                                                       Drama History Romance War
# Huevos: Little Rooster's Egg-cellent Adventure  Adventure Animation Comedy Family Fantasy
# Central Station                                                                     Drama
# Bad Education                                                                 Crime Drama
# Ong-Bak: The Thai Warrior                                           Action Crime Thriller
#
#                                                original_release_markets_num  \
# title
# Padmaavat                                                              None
# Huevos: Little Rooster's Egg-cellent Adventure                         None
# Central Station                                                    Domestic
# Bad Education                                                            35
# Ong-Bak: The Thai Warrior                                              None
#
#                                                                                              crew  \
# title
# Padmaavat                                       Sanjay Leela Bhansali Director, Prakash Kapadi...
# Huevos: Little Rooster's Egg-cellent Adventure  Gabriel Riva Palacio Alatriste Director, Rodol...
# Central Station                                 Walter Salles Director, Marcos Bernstein Write...
# Bad Education                                   Pedro Almodóvar Director, Pedro Almodóvar Writ...
# Ong-Bak: The Thai Warrior                       Prachya Pinkaew Director, Panna Rittikrai Writ...
#
#                                                                                              cast  \
# title
# Padmaavat                                       Deepika Padukone, Ranveer Singh, Shahid Kapoor...
# Huevos: Little Rooster's Egg-cellent Adventure  Bruno Bichir, Carlos Espejel, Angélica Vale, O...
# Central Station                                 Fernanda Montenegro, Vinícius de Oliveira, Mar...
# Bad Education                                   Gael García Bernal, Fele Martínez, Javier Cáma...
# Ong-Bak: The Thai Warrior                       Tony Jaa, Petchtai Wongkamlao, Pumwaree Yodkam...
#
#                                                 earliest_release_location_opening_gross  \
# title
# Padmaavat                                                                     4493384.0
# Huevos: Little Rooster's Egg-cellent Adventure                                3424702.0
# Central Station                                                                 35708.0
# Bad Education                                                                  147370.0
# Ong-Bak: The Thai Warrior                                                     1334869.0
#
#                                                 earliest_release_location_original_gross
# title
# Padmaavat                                                                       11846060
# Huevos: Little Rooster's Egg-cellent Adventure                                   9080818
# Central Station                                                                  5969553
# Bad Education                                                                    5211842
# Ong-Bak: The Thai Warrior                                                        4563167

# %%
different_indices2 = fl_movies_page_info[~fl_movies_page_info.index.isin(fl_movies.index)]
different_indices2.index
# Out:
# Index(['Server Error', 'Huevos: Little Rooster's Egg', 'Server Error_2',
#        'Server Error_2', 'Ong', 'Server Error_2', 'La veuve de Saint', 'Veer',
#        'Dans une galaxie près de chez vous', 'Server Error_2', 'Hum Saath',
#        'Salaam', 'Kon', 'Server Error_2', 'Server Error_2',
#        'Xiu Xiu: The Sent', 'Server Error_2', 'The 100 Year', 'Delhi',
#        'The Ex', 'Server Error_2', 'Non', 'Mid', 'Jaan', 'Teo',
#        'Server Error_2', 'Server Error_2', 'Head', 'Baise', 'Server Error_2',
#        'Ju', 'Anonyma', '3', 'Angel', 'Live', 'Lilya 4', 'Server Error_2',
#        'Mughal', '3_2', 'Luck_2', 'Shortkut', 'Tazza: One',
#        'I Married an Anti', 'Hara', 'Cet amour', 'Server Error_2',
#        'Server Error_2', 'Server Error_2', 'Britt', 'Server Error_2',
#        'All About Lily Chou', 'Brodeuses', 'Haikara', 'Ong_2',
#        'Server Error_2', 'Server Error_2', 'Server Error_2',
#        'Arabian Nights: Volume 3', 'Demi'],
#       dtype='object', name='title')

# %%
fl_movies_page_info.drop(different_indices2.index, inplace=True)

# %%
fl_movies_page_info.shape
# Out:
# (2440, 15)

# %%
fl_movies_page_info_2.index = fl_movies_page_info_2.index.where(~fl_movies_page_info_2.index.duplicated(), fl_movies_page_info_2.index + '_2')

# %%
fl_movies_page_info = pd.concat((fl_movies_page_info, fl_movies_page_info_2), axis=0)

# %%
fl_movies_page_info.shape
# Out:
# (2499, 15)

# %%
fl_movies_page_info.index = fl_movies_page_info.index.where(~fl_movies_page_info.index.duplicated(), fl_movies_page_info.index + '_2')

# %%
fl_movies = fl_movies.merge(fl_movies_page_info, left_index=True, right_index=True)
fl_movies
# Out:
#                                                             link_stub  \
# Crouching Tiger, Hidden Dragon   /title/tt0190332/?ref_=bo_ge_table_1
# Life Is Beautiful                /title/tt0118799/?ref_=bo_ge_table_2
# Hero                             /title/tt0299977/?ref_=bo_ge_table_3
# Parasite                         /title/tt6751668/?ref_=bo_ge_table_4
# Instructions Not Included        /title/tt2378281/?ref_=bo_ge_table_5
# ...                                                               ...
# Falling                         /title/tt0832347/?ref_=bo_ge_table_95
# Canary                          /title/tt0468777/?ref_=bo_ge_table_96
# Tasuma                          /title/tt0423325/?ref_=bo_ge_table_97
# News from Planet Mars           /title/tt5038358/?ref_=bo_ge_table_98
# Dog Eat Dog                     /title/tt1157631/?ref_=bo_ge_table_99
#
#                                gross_rank                           title  \
# Crouching Tiger, Hidden Dragon          1  Crouching Tiger, Hidden Dragon
# Life Is Beautiful                       2               Life Is Beautiful
# Hero                                    3                            Hero
# Parasite                                4                        Parasite
# Instructions Not Included               5       Instructions Not Included
# ...                                   ...                             ...
# Falling                             2,495                         Falling
# Canary                              2,496                          Canary
# Tasuma                              2,497                          Tasuma
# News from Planet Mars               2,498           News from Planet Mars
# Dog Eat Dog                         2,499                     Dog Eat Dog
#
#                                lifetime_gross max_theaters domestic_opening_x  \
# Crouching Tiger, Hidden Dragon   $128,078,872        2,027           $663,205
# Life Is Beautiful                 $57,247,384        1,136           $118,920
# Hero                              $53,710,019        2,175        $17,800,000
# Parasite                          $53,369,749        2,001           $393,216
# Instructions Not Included         $44,467,206          978         $7,846,426
# ...                                       ...          ...                ...
# Falling                                  $509            1               $509
# Canary                                   $504            1               $504
# Tasuma                                   $479            1               $281
# News from Planet Mars                    $310            1                $24
# Dog Eat Dog                               $80            1                $80
#
#                                num_opening_theaters release_date_x  \
# Crouching Tiger, Hidden Dragon                   16    Dec 8, 2000
# Life Is Beautiful                                 6   Oct 23, 1998
# Hero                                          2,031   Aug 27, 2004
# Parasite                                          3   Oct 11, 2019
# Instructions Not Included                       348   Aug 30, 2013
# ...                                             ...            ...
# Falling                                           1   Jun 29, 2007
# Canary                                            1   Jul 25, 2008
# Tasuma                                            1   Jul 30, 2004
# News from Planet Mars                             1   Jul 22, 2016
# Dog Eat Dog                                       1   Jan 23, 2009
#
#                                     domestic_distributor_x  \
# Crouching Tiger, Hidden Dragon  Sony Pictures Classics\n\n
# Life Is Beautiful                              Miramax\n\n
# Hero                                           Miramax\n\n
# Parasite                                          Neon\n\n
# Instructions Not Included                    Lionsgate\n\n
# ...                                                    ...
# Falling                             Kino International\n\n
# Canary                            ImaginAsian Pictures\n\n
# Tasuma                           ArtMattan Productions\n\n
# News from Planet Mars                      Kino Lorber\n\n
# Dog Eat Dog                                  IFC Films\n\n
#
#                                 domestic_total_gross  ...  release_date_y  \
# Crouching Tiger, Hidden Dragon           128078872.0  ...      2000-12-08
# Life Is Beautiful                         57563264.0  ...      1998-10-23
# Hero                                      53710019.0  ...      2002-12-19
# Parasite                                  53369749.0  ...      2019-05-30
# Instructions Not Included                 44467206.0  ...      2013-08-30
# ...                                              ...  ...             ...
# Falling                                        509.0  ...      2007-06-29
# Canary                                         504.0  ...      2008-07-25
# Tasuma                                         479.0  ...      2004-07-30
# News from Planet Mars                          310.0  ...      2016-03-09
# Dog Eat Dog                                     80.0  ...      2009-01-23
#
#                                release_location  rating  runtime  \
# Crouching Tiger, Hidden Dragon         Domestic   PG-13      NaN
# Life Is Beautiful                      Domestic   PG-13    116.0
# Hero                                APAC, China   PG-13      NaN
# Parasite                            South Korea       R    132.0
# Instructions Not Included              Domestic   PG-13    115.0
# ...                                         ...     ...      ...
# Falling                                Domestic    None     88.0
# Canary                                 Domestic    None    132.0
# Tasuma                                 Domestic    None     90.0
# News from Planet Mars                   Belgium    None    101.0
# Dog Eat Dog                            Domestic    None    106.0
#
#                                                           genres  \
# Crouching Tiger, Hidden Dragon  Action Adventure Fantasy Romance
# Life Is Beautiful                       Comedy Drama Romance War
# Hero                                    Action Adventure History
# Parasite                                   Comedy Drama Thriller
# Instructions Not Included                           Comedy Drama
# ...                                                          ...
# Falling                                                    Drama
# Canary                                                     Drama
# Tasuma                                                     Drama
# News from Planet Mars                               Comedy Drama
# Dog Eat Dog                                             Thriller
#
#                                original_release_markets_num  \
# Crouching Tiger, Hidden Dragon                            9
# Life Is Beautiful                           Domestic, China
# Hero                                                   None
# Parasite                                                 34
# Instructions Not Included                                15
# ...                                                     ...
# Falling                                                None
# Canary                                                 None
# Tasuma                                                 None
# News from Planet Mars                                     3
# Dog Eat Dog                                        Domestic
#
#                                                                              crew  \
# Crouching Tiger, Hidden Dragon  Ang Lee Director, Hui-Ling Wang Writer, James ...
# Life Is Beautiful               Roberto Benigni Director, Vincenzo Cerami Writ...
# Hero                            Yimou Zhang Director, Feng Li Writer, Yimou Zh...
# Parasite                        Bong Joon Ho Director, Bong Joon Ho Writer, Bo...
# Instructions Not Included       Eugenio Derbez Director, Guillermo Ríos Writer...
# ...                                                                           ...
# Falling                         Barbara Albert Director, Barbara Albert Writer...
# Canary                          Akihiko Shiota Director, Akihiko Shiota Writer...
# Tasuma                          Kollo Sanou Director, Cheick Tidiane Seck Comp...
# News from Planet Mars           Dominik Moll Director, Dominik Moll Writer, Gi...
# Dog Eat Dog                     Carlos Moreno Director, Alonso Torres Writer, ...
#
#                                                                              cast  \
# Crouching Tiger, Hidden Dragon  Chow Yun-Fat, Michelle Yeoh, Ziyi Zhang, Chen ...
# Life Is Beautiful               Roberto Benigni, Nicoletta Braschi, Giorgio Ca...
# Hero                            Jet Li, Tony Chiu-Wai Leung, Maggie Cheung, Zi...
# Parasite                        Kang-ho Song, Sun-kyun Lee, Yeo-jeong Cho, Woo...
# Instructions Not Included       Eugenio Derbez, Karla Souza, Jessica Lindsey, ...
# ...                                                                           ...
# Falling                         Nina Proll, Birgit Minichmayr, Kathrin Resetar...
# Canary                          Hôshi Ishida, Mitsuki Tanimura, Hidetoshi Nish...
# Tasuma                                           Serge Henri, Besani Raoul Khalil
# News from Planet Mars           François Damiens, Vincent Macaigne, Veerle Bae...
# Dog Eat Dog                     Marlon Moreno, Óscar Borda, Álvaro Rodríguez, ...
#
#                                earliest_release_location_opening_gross  \
# Crouching Tiger, Hidden Dragon                                663205.0
# Life Is Beautiful                                             118920.0
# Hero                                                        17800000.0
# Parasite                                                      393216.0
# Instructions Not Included                                    7846426.0
# ...                                                                ...
# Falling                                                          509.0
# Canary                                                           504.0
# Tasuma                                                           281.0
# News from Planet Mars                                             24.0
# Dog Eat Dog                                                       80.0
#
#                                earliest_release_location_original_gross
# Crouching Tiger, Hidden Dragon                              128078872.0
# Life Is Beautiful                                            57247384.0
# Hero                                                         53710019.0
# Parasite                                                     53369749.0
# Instructions Not Included                                    44467206.0
# ...                                                                 ...
# Falling                                                           509.0
# Canary                                                            504.0
# Tasuma                                                            479.0
# News from Planet Mars                                             310.0
# Dog Eat Dog                                                        80.0
#
# [2499 rows x 24 columns]

# %%
#immediately pickling dataframe
fl_movies.to_pickle('fl_movies.pickle')
